# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Bahnar-English-Machine-Translation/4-training/3-bdq-eng-augmented/1-transformer-opennmt
# Out:
# /content/drive/MyDrive/Bahnar-English-Machine-Translation/4-training/3-bdq-eng-augmented/1-transformer-opennmt

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Train a Subwording Model

# %%
# !pip install sentencepiece

# %%
import sentencepiece as spm

# %%
train_source_file = "/content/drive/MyDrive/Bahnar-English-Machine-Translation/3-dataset/bdq-eng/1-train/2-with_aug/train-val-split/bdq-vie-eng.train.bdq"
train_target_file = "/content/drive/MyDrive/Bahnar-English-Machine-Translation/3-dataset/bdq-eng/1-train/2-with_aug/train-val-split/bdq-vie-eng.train.eng"

# %%
source_train_value = '--input='+train_source_file+' --model_prefix=2-subwording-model/bdq-source --vocab_size=14000 --hard_vocab_limit=false --model_type=bpe --split_digits=true'
spm.SentencePieceTrainer.train(source_train_value)
print("Done, training a SentencepPiece model for the Source finished successfully!")
# Out:
# Done, training a SentencepPiece model for the Source finished successfully!

# %%
example = "Đawit apinh dơ̆ng: Lu kon pơlei Kêila gô jao inh păng lu bơngai kiơ̆ inh lăm tơpang ti Sôl hă"
source_model_bpe = "2-subwording-model/bdq-source.model"
sp = spm.SentencePieceProcessor()
sp.load(source_model_bpe)
print(sp.encode_as_pieces(example))
# Out:
# ['▁Đawit', '▁apinh', '▁dơ̆ng', ':', '▁Lu', '▁kon', '▁pơlei', '▁Kêila', '▁gô', '▁jao', '▁inh', '▁păng', '▁lu', '▁bơngai', '▁kiơ̆', '▁inh', '▁lăm', '▁tơpang', '▁ti', '▁Sôl', '▁hă']

# %%
# !python /content/drive/MyDrive/Bahnar-English-Machine-Translation/2-data-processing/subwording/2-subword.py 2-subwording-model/bdq-source.model /content/drive/MyDrive/Bahnar-English-Machine-Translation/3-dataset/bdq-eng/1-train/2-with_aug/train-val-split/bdq-vie-eng.train.bdq 1-subworded-data/bdq-eng.train.subword.bdq

# %%
# !python /content/drive/MyDrive/Bahnar-English-Machine-Translation/2-data-processing/subwording/2-subword.py 2-subwording-model/bdq-source.model /content/drive/MyDrive/Bahnar-English-Machine-Translation/3-dataset/bdq-eng/1-train/2-with_aug/train-val-split/bdq-vie-eng.val.bdq 1-subworded-data/bdq-eng.val.subword.bdq

# %%
# !head -n 10 1-subworded-data/bdq-eng.val.subword.bdp
# Out:
# ▁mơ̆u
# ▁Iĕm ▁hăm ▁lah ▁ăn ▁kơ ▁aseh ▁kơdâu ▁kơpal ▁tơmo ▁tih
# ▁Pham ▁vi , ▁kuy ▁mô ▁weng ▁jơnang ▁pơm
# ▁ + ▁‘ Năr ▁mă ▁pêng : ▁Đơ̆ng ▁rŏng ▁kơ ▁ƀuh ▁nhŭng , ▁adrol ▁kơ ▁et ▁xa , ▁unh ▁hnam ▁‘ nhăk ▁axong ▁tơmam ▁‘ nao ▁truh ▁pơxat ▁ăn ▁bơngai ▁lôch ▁păng ▁hmoi ▁‘ măng ▁mă ▁hơtuch ▁vă ▁tơklăh ▁hlŏng ▁hloi ▁hăm ▁bơngai ▁hiong , ▁lơ̆m ▁kơplăh ▁noh ▁tơm ▁hnam ▁tơbang ▁nơ̆r ▁xoi ▁atŭm ▁hăm ▁khôi ▁rok ▁tăp ▁dăr ▁pơxat ▁atŭm ▁hơ xuang , ▁tôm ▁chêng , ▁nŏ ▁nam ▁păng ▁rang ▁raih ▁truh ▁lai ▁yơ ▁jơmŭl ▁unh ▁păt ▁đĭ ▁noh ▁rim ▁bơngai ▁pơtơm ▁vih .
# ▁Noh ▁jing ▁minh ▁năr ▁Kră ▁Yang ▁đĕch ▁băt ; ▁ưh ▁kơ ▁sĭ ▁kơ ' năr ▁dah ▁kơmăng , ▁mă - lei ▁dah ▁kơsơ̆ ▁truh ▁boih ▁gô ▁đei ▁hơdah
# ▁Yua ▁kơ ▁lăm ▁chăl ▁Đawit ▁păng ▁Asap ▁sơ̆ , ▁đei ▁minh ▁' nu ▁kră ▁pơgơ̆r ▁wei - lăng ▁lu ▁bơngai ▁hơri , ▁đei ▁' bai ▁hơri ▁bơnê ▁kơkuh ▁ư - ang ▁kơ ▁Kră ▁Yang ▁' Bok ▁Kei - Dei
# ▁' lơ̆p ▁loi ▁adrol
# ...

# %%
target_train_value = '--input='+train_target_file+' --model_prefix=2-subwording-model/eng-target --vocab_size=32000 --hard_vocab_limit=false --model_type=bpe --split_digits=true'
spm.SentencePieceTrainer.train(target_train_value)
print("Done, training a SentencepPiece model for the Target finished successfully!")
# Out:
# Done, training a SentencepPiece model for the Target finished successfully!

# %%
# !python /content/drive/MyDrive/Bahnar-English-Machine-Translation/2-data-processing/subwording/2-subword.py 2-subwording-model/eng-target.model /content/drive/MyDrive/Bahnar-English-Machine-Translation/3-dataset/bdq-eng/1-train/2-with_aug/train-val-split/bdq-vie-eng.train.eng 1-subworded-data/bdq-eng.train.subword.eng
# Out:
# Model: 2-subwording-model/eng-target.model
# Dataset: /content/drive/MyDrive/Bahnar-English-Machine-Translation/3-dataset/bdq-eng/1-train/2-with_aug/train-val-split/bdq-vie-eng.train.eng
# Done subwording the file! Output: 1-subworded-data/bdq-eng.train.subword.eng

# %%
# !python /content/drive/MyDrive/Bahnar-English-Machine-Translation/2-data-processing/subwording/2-subword.py 2-subwording-model/eng-target.model /content/drive/MyDrive/Bahnar-English-Machine-Translation/3-dataset/bdq-eng/1-train/2-with_aug/train-val-split/bdq-vie-eng.val.eng 1-subworded-data/bdq-eng.val.subword.eng
# Out:
# Model: 2-subwording-model/eng-target.model
# Dataset: /content/drive/MyDrive/Bahnar-English-Machine-Translation/3-dataset/bdq-eng/1-train/2-with_aug/train-val-split/bdq-vie-eng.val.eng
# Done subwording the file! Output: 1-subworded-data/bdq-eng.val.subword.eng

# %%
# !head -n 10 1-subworded-data/bdq-eng.val.subword.eng
# Out:
# ▁tastes ,
# ▁Shall ▁horses ▁run ▁upon ▁the ▁rock
# ▁Scope , ▁scale ▁and ▁duration ▁of ▁implementation
# ▁ + ▁On ▁the ▁third ▁day : ▁After ▁the ▁pork ▁is ▁finished , ▁before ▁eating ▁and ▁drinking , ▁the ▁family ▁brings ▁the ▁shares ▁into ▁the ▁new ▁grave ▁house ▁for ▁the ▁deceased ▁and ▁weeps ▁for ▁the ▁last ▁time ▁goodbye ▁to ▁the ▁deceased ▁relatives , ▁while ▁the ▁host ▁reads ▁the ▁prayers ▁and ▁rituals ▁and ▁walks ▁around ▁the ▁grave ▁house ▁dancing , ▁playing ▁drums , ▁gongs , ▁t amb our ines ▁and ▁cymbals ▁until ▁the ▁fire ▁is ▁completely ▁extinguished ▁and ▁everyone ▁leaves .
# ▁but ▁it ▁shall ▁be ▁one ▁day ▁which ▁shall ▁be ▁known ▁to ▁the ▁LORD , ▁not ▁day , ▁nor ▁night : ▁but ▁it ▁shall ▁come ▁to ▁pass , ▁that ▁at ▁evening ▁time ▁it ▁shall ▁be ▁light
# ▁For ▁in ▁the ▁days ▁of ▁David ▁and ▁Asaph ▁of ▁old ▁there ▁were ▁chief ▁of ▁the ▁singers , ▁and ▁songs ▁of ▁praise ▁and ▁thanksgiving ▁unto ▁God
# ▁young ▁out ,
# ...

# %% [markdown]
# # Training

# %% [markdown]
# ## Training Configuration

# %%
# !pip3 install OpenNMT-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.3/257.3 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.8/36.8 MB 28.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 58.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 67.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 97.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.7/227.7 kB 30.0 MB/s eta 0:00:00
# ...

# %%
# Create the YAML configuration file
config = '''# config.yaml


## Where the samples will be written
save_data: vocabulary

# Training files
data:
    corpus_1:
        path_src: 1-subworded-data/bdq-eng.train.subword.bdq
        path_tgt: 1-subworded-data/bdq-eng.train.subword.eng
        transforms: [filtertoolong]
    valid:
        path_src: 1-subworded-data/bdq-eng.val.subword.bdq
        path_tgt: 1-subworded-data/bdq-eng.val.subword.eng
        transforms: [filtertoolong]

# Vocabulary files, generated by onmt_build_vocab
src_vocab: vocabulary/bdq-source.vocab
tgt_vocab: vocabulary/eng-target.vocab

# Vocabulary size - should be the same as in sentence piece
src_vocab_size: 14000
tgt_vocab_size: 32000

# Filter out source/target longer than n if [filtertoolong] enabled
src_seq_length: 150
src_seq_length: 150

# Tokenization options
src_subword_model: 2-subwording-model/bdq-source.model
tgt_subword_model: 2-subwording-model/eng-target.model

# Where to save the log file and the output models/checkpoints
log_file: train.log
save_model: 4-model-checkpoints/bavien

# Stop training if it does not imporve after n validations
early_stopping: 4

# Default: 5000 - Save a model checkpoint for each n
save_checkpoint_steps: 1000

# To save space, limit checkpoints to last n
# keep_checkpoint: 3

seed: 3435

# Default: 100000 - Train the model to max n steps
# Increase to 200000 or more for large datasets
# For fine-tuning, add up the required steps to the original steps
train_steps: 3000

# Default: 10000 - Run validation after n steps
valid_steps: 1000

# Default: 4000 - for large datasets, try up to 8000
warmup_steps: 1000
report_every: 100

# Number of GPUs, and IDs of GPUs
world_size: 1
gpu_ranks: [0]

# Batching
bucket_size: 262144
num_workers: 0  # Default: 2, set to 0 when RAM out of memory
batch_type: "tokens"
batch_size: 4096   # Tokens per batch, change when CUDA out of memory
valid_batch_size: 2048
max_generator_batches: 2
accum_count: [4]
accum_steps: [0]

# Optimization
model_dtype: "fp16"
optim: "adam"
learning_rate: 2
# warmup_steps: 8000
decay_method: "noam"
adam_beta2: 0.998
max_grad_norm: 0
label_smoothing: 0.1
param_init: 0
param_init_glorot: true
normalization: "tokens"

# Model
encoder_type: transformer
decoder_type: transformer
position_encoding: true
enc_layers: 6
dec_layers: 6
heads: 8
hidden_size: 512
word_vec_size: 512
transformer_ff: 2048
dropout_steps: [0]
dropout: [0.1]
attention_dropout: [0.1]
'''

with open("config.yaml", "w+") as config_yaml:
  config_yaml.write(config)

# %%
# !cat config.yaml
# Out:
# # config.yaml
#
#
# ## Where the samples will be written
# save_data: vocabulary
#
# # Training files
# data:
#     corpus_1:
#         path_src: 1-subworded-data/bdq-eng.train.subword.bdq
#         path_tgt: 1-subworded-data/bdq-eng.train.subword.eng
#         transforms: [filtertoolong]
#     valid:
#         path_src: 1-subworded-data/bdq-eng.val.subword.bdq
#         path_tgt: 1-subworded-data/bdq-eng.val.subword.eng
#         transforms: [filtertoolong]
#
# # Vocabulary files, generated by onmt_build_vocab
# src_vocab: vocabulary/bdq-source.vocab
# tgt_vocab: vocabulary/eng-target.vocab
#
# # Vocabulary size - should be the same as in sentence piece
# src_vocab_size: 14000
# tgt_vocab_size: 32000
#
# # Filter out source/target longer than n if [filtertoolong] enabled
# src_seq_length: 150
# src_seq_length: 150
#
# # Tokenization options
# src_subword_model: 2-subwording-model/bdq-source.model
# tgt_subword_model: 2-subwording-model/eng-target.model
#
# ...

# %% [markdown]
# ## Build Vocab

# %%
# !nproc --all
# Out:
# 2

# %%
# !onmt_build_vocab -config config.yaml -n_sample -1 -num_threads 2
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2024-02-08 03:42:03,799 INFO] Counter vocab from -1 samples.
# [2024-02-08 03:42:03,799 INFO] n_sample=-1: Build vocab on full datasets.
# [2024-02-08 03:42:05,390 INFO] * Transform statistics for corpus_1(50.00%):
# 			* FilterTooLongStats(filtered=5)
#
# [2024-02-08 03:42:05,446 INFO] * Transform statistics for corpus_1(50.00%):
# 			* FilterTooLongStats(filtered=13)
#
# [2024-02-08 03:42:05,492 INFO] Counters src: 12247
# [2024-02-08 03:42:05,493 INFO] Counters tgt: 19446

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-0e2a61bb-e223-6698-562b-f60bea1f1f7a)

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

gpu_memory = torch.cuda.mem_get_info(0)
print("Free GPU memory:", gpu_memory[0]/1024**2, "out of:", gpu_memory[1]/1024**2)
# Out:
# True
# Tesla T4
# Free GPU memory: 14999.0625 out of: 15102.0625

# %% [markdown]
# ## Training

# %%
# !onmt_train -config config.yaml

# %% [markdown]
# # Translation

# %%
# !pip3 install ctranslate2

# %%
# !ct2-opennmt-py-converter --model_path 4-model-checkpoints/bavien_step_3000.pt --output_dir 4-model-checkpoints/bavien_ctranslate2 --quantization int8

# %%
# !python /content/drive/MyDrive/bdq-mt/evaluation/translate.py  /content/drive/MyDrive/Bahnar-English-Machine-Translation/3-dataset/bdq-eng/2-test/bdq-eng.test.bdq 5-model-prediction/bdq-eng.test.bdq.translated.eng  2-subwording-model/bdq-source.model 2-subwording-model/eng-target.model 4-model-checkpoints/bavien_ctranslate2
# Out:
# Done

# %%
# !head -n 5 5-model-prediction/bdq-eng.test.bdq.translated.eng
# Out:
# The district protection forest management board has contracted 6 collectives and 184 households in villages in the commune for management and protection with a total funding of over VND 204 million.
# not floating,
# And they sent unto the children of Canaan, and to the Amorites, and to the land of the Amorites, and from the children of Ammon, and from the mount Hermon, and from the mount Hermon, and the areas of Arnon, even unto the street of the country
# As the mountain,
# And this is the promise that he hath promised us, even eternal life

# %%
# !head -n 5 /content/drive/MyDrive/Bahnar-English-Machine-Translation/3-dataset/bdq-eng/2-test/bdq-eng.test.eng
# Out:
# The district protection forest management board has contracted 6 collectives and 184 households in villages in the commune for management and protection with a total funding of over VND 2 billion and 604 million.
# woke up,
# and to the Canaanite on the east and on the west, and to the Amorite, and the Hittite, and the Perizzite, and the Jebusite in the mountains, and to the Hivite under Hermon in the land of Mizpeh
# Accreditation Level
# God having provided some better thing for us, that they without us should not be made perfect

# %% [markdown]
# # Evaluation

# %%
# !pip3 install sacrebleu

# %%
# !python3 /content/drive/MyDrive/bdq-mt/evaluation/eval-metrics.py /content/drive/MyDrive/Bahnar-English-Machine-Translation/3-dataset/bdq-eng/2-test/bdq-eng.test.eng 5-model-prediction/bdq-eng.test.bdq.translated.eng
# Out:
# BLEU:  37.74
# CHRF: 53.29
# TER: 65.02
